# %% [markdown]
# <a href="https://colab.research.google.com/github/DjengoFang/Financial-Engineering-Ruppert-Matteson-/blob/main/3.10.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import optimize

# %%
url_m = 'https://raw.githubusercontent.com/DjengoFang/Financial-Engineering-Ruppert-Matteson-/main/datasets/mk.maturity.csv'
url = 'https://raw.githubusercontent.com/DjengoFang/Financial-Engineering-Ruppert-Matteson-/main/datasets/mk.zero2.csv'
maturity = pd.read_csv(url_m)
zero2 = pd.read_csv(url)

# %%
maturity.head()
# Out:
#    Maturity
# 0     0.083
# 1     0.167
# 2     0.250
# 3     0.333
# 4     0.417

# %%
zero2.head(10)
# Out:
#     X.Y..m..d      M.1      M.2      M.3      M.4      M.5      M.6      M.7  \
# 0  1985-08-01  0.07242  0.07212  0.07271  0.07372  0.07469  0.07546  0.07609
# 1  1985-09-01  0.07109  0.07189  0.07255  0.07314  0.07375  0.07443  0.07519
# 2  1985-10-01  0.07165  0.07297  0.07354  0.07389  0.07439  0.07509  0.07580
# 3  1985-11-01  0.06592  0.07164  0.07381  0.07404  0.07411  0.07460  0.07529
# 4  1985-12-01  0.06237  0.06895  0.07169  0.07228  0.07256  0.07297  0.07344
# 5  1986-01-01  0.06805  0.07064  0.07163  0.07187  0.07216  0.07268  0.07324
# 6  1986-02-01  0.06887  0.07116  0.07200  0.07204  0.07202  0.07219  0.07246
# 7  1986-03-01  0.06579  0.06490  0.06464  0.06466  0.06471  0.06474  0.06487
# 8  1986-04-01  0.05981  0.06100  0.06178  0.06233  0.06273  0.06304  0.06332
# 9  1986-05-01  0.06234  0.06339  0.06426  0.06497  0.06553  0.06595  0.06632
#
#        M.8      M.9  ...     M.46     M.47     M.48  M.49  M.50  M.51  M.52  \
# ...

# %%
zero2.plot(x = 'X.Y..m..d', y =['M.1', 'M.24', 'M.48'], figsize=(20, 10))

# %%
intForward = maturity['Maturity']*zero2['M.1']
