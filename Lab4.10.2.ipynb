# %% [markdown]
# <a href="https://colab.research.google.com/github/DjengoFang/Financial-Engineering-Ruppert-Matteson-/blob/main/Lab4.10.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.stats import shapiro
from scipy.stats import t
from scipy.stats import norm
import statsmodels.api as sm
import pylab as py
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/DjengoFang/Financial-Engineering-Ruppert-Matteson-/main/datasets/MCD_PriceDaily.csv'
data = pd.read_csv(url)
data.head(5)
# Out:
#        Date   Open   High    Low  Close    Volume  Adj Close
# 0  1/4/2010  62.63  63.07  62.31  62.78   5839300      53.99
# 1  1/5/2010  62.66  62.75  62.19  62.30   7099000      53.58
# 2  1/6/2010  62.20  62.41  61.06  61.45  10551300      52.85
# 3  1/7/2010  61.25  62.34  61.11  61.90   7517700      53.24
# 4  1/8/2010  62.27  62.41  61.60  61.84   6107300      53.19

# %%
data.plot(x="Date", subplots=True, layout=(3,2), figsize=(30,30), sharex=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff530d82c10>,
# ...
#       dtype=object)

# %% [markdown]
# # Problem 9
# ## The Adj Close plot shows no tendency to revert to a mean so the series is nonstationary.

# %% [markdown]
# # Problem 10

# %%
data['Log Return'] = np.log(data['Adj Close']) - np.log(data['Adj Close'].shift(1))
data.head(5)
# Out:
#        Date   Open   High    Low  Close    Volume  Adj Close  Log Return
# 0  1/4/2010  62.63  63.07  62.31  62.78   5839300      53.99         NaN
# 1  1/5/2010  62.66  62.75  62.19  62.30   7099000      53.58   -0.007623
# 2  1/6/2010  62.20  62.41  61.06  61.45  10551300      52.85   -0.013718
# 3  1/7/2010  61.25  62.34  61.11  61.90   7517700      53.24    0.007352
# 4  1/8/2010  62.27  62.41  61.60  61.84   6107300      53.19   -0.000940

# %%
data.plot(x='Date', y='Log Return', figsize=(30,10))

# %% [markdown]
# # Problem 11

# %%
data['Log Return'].plot.hist(bins=80)

# %%
sm.qqplot(100*data['Log Return'], line ='45')
